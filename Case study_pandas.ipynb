# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\Joshi-PC\\Desktop\\python\\top50_sportify_songs.csv', encoding = 'latin-1')

# %%
df
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute',
#        'Energy', 'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.',
#        'Length.', 'Acousticness..', 'Speechiness.', 'Popularity'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
df.shape
# Out:
# (50, 14)

# %%
# Display details of the songs that have popularity above 80
df[df['Popularity']> 80]
# Out:
#     Unnamed: 0                                         Track.Name  \
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# 13          14                                 Otro Trago - Remix
# ...

# %%
# Which is having maximum length, beats per minute?
df[df['Length.'] == df['Length.'].max()].shape
# Out:
# (1, 14)

# %%
df[df['Beats.Per.Minute']== df['Beats.Per.Minute'].max()].shape
# Out:
# (1, 14)

# %%
# Which is having minimum length, beats per minute?
df[df['Length.'] == df['Length.'].min()].shape
# Out:
# (1, 14)

# %%
df[df['Beats.Per.Minute']== df['Beats.Per.Minute'].min()].shape
# Out:
# (2, 14)

# %%
# Create new column to store string length
df['Track.Name_len'] = df['Track.Name'].str.len()
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
# create new column to store first name of each artist
df['first_name']= df ['Artist.Name'].str.split().str[0]
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
# how many songs from "dance pop" genre
df[df['Genre']== 'dance pop'].shape
# Out:
# (8, 16)

# %%
# what is average length for each genre
df.groupby(['Genre'])['Length.'].mean()
# Out:
# Genre
# atl hip hop         200.000000
# australian pop      210.000000
# big room            164.000000
# boy band            181.000000
# brostep             198.000000
# canadian hip hop    193.000000
# canadian pop        191.000000
# country rap         136.000000
# dance pop           202.625000
# dfw rap             166.500000
# edm                 218.666667
# electropop          194.500000
# escape room         173.000000
# latin               225.200000
# panamanian pop      257.000000
# pop                 195.428571
# pop house           153.000000
# r&b en espanol      162.000000
# reggaeton           213.500000
# reggaeton flow      305.500000
# trap music          131.000000
# Name: Length., dtype: float64

# %%
df.groupby(['Genre']).groups
# Out:
# {'atl hip hop': Int64Index([33], dtype='int64'),
#  'australian pop': Int64Index([26], dtype='int64'),
#  'big room': Int64Index([35], dtype='int64'),
#  'boy band': Int64Index([38], dtype='int64'),
#  'brostep': Int64Index([45, 47], dtype='int64'),
#  'canadian hip hop': Int64Index([14, 18, 27], dtype='int64'),
#  'canadian pop': Int64Index([0, 25], dtype='int64'),
#  'country rap': Int64Index([8, 21], dtype='int64'),
#  'dance pop': Int64Index([2, 11, 15, 31, 34, 39, 41, 42], dtype='int64'),
#  'dfw rap': Int64Index([4, 17], dtype='int64'),
#  'edm': Int64Index([30, 40, 48], dtype='int64'),
#  'electropop': Int64Index([9, 24], dtype='int64'),
#  'escape room': Int64Index([19], dtype='int64'),
#  'latin': Int64Index([16, 23, 28, 29, 46], dtype='int64'),
#  'panamanian pop': Int64Index([13, 36], dtype='int64'),
#  'pop': Int64Index([3, 5, 7, 12, 37, 43, 49], dtype='int64'),
#  'pop house': Int64Index([20], dtype='int64'),
#  'r&b en espanol': Int64Index([44], dtype='int64'),
# ...

# %%
# what is average length for each artist
df.groupby(['Artist.Name'])['Length.'].mean()
# Out:
# Artist.Name
# Ali Gatie           213.0
# Anuel AA            302.0
# Ariana Grande       182.5
# Bad Bunny           251.0
# Billie Eilish       194.5
# Chris Brown         261.0
# DJ Snake            185.0
# Daddy Yankee        193.0
# Drake               205.0
# Ed Sheeran          196.5
# J Balvin            232.5
# Jhay Cortez         309.0
# Jonas Brothers      181.0
# Katy Perry          224.0
# Khalid              198.0
# Kygo                228.0
# Lady Gaga           216.0
# Lauv                199.0
# Lewis Capaldi       182.0
# Lil Nas X           136.0
# Lil Tecca           131.0
# Lizzo               173.0
# Lunay               266.0
# MEDUZA              153.0
# Maluma              176.0
# Marshmello          198.0
# Martin Garrix       164.0
# Nicky Jam           202.0
# Post Malone         166.5
# ROSALÍA             162.0
# Sam Smith           202.0
# Sech                257.0
# Shawn Mendes        191.0
# Taylor Swift        171.0
# The Chainsmokers    214.0
# ...

# %%
# what is maximum 'Length' for each genre
df.groupby(['Genre'])['Length.'].max()
# Out:
# Genre
# atl hip hop         200
# australian pop      210
# big room            164
# boy band            181
# brostep             214
# canadian hip hop    213
# canadian pop        191
# country rap         157
# dance pop           261
# dfw rap             175
# edm                 228
# electropop          195
# escape room         173
# latin               266
# panamanian pop      288
# pop                 220
# pop house           153
# r&b en espanol      162
# reggaeton           251
# reggaeton flow      309
# trap music          131
# Name: Length., dtype: int64

# %%
#df.groupby(['Genre'])['Length.'].agg({'Length.':'mean'})

# %%
# what is maximum 'length' for each artist
df.groupby(['Artist.Name'])['Length.'].max()
# Out:
# Artist.Name
# Ali Gatie           213
# Anuel AA            302
# Ariana Grande       186
# Bad Bunny           251
# Billie Eilish       195
# Chris Brown         261
# DJ Snake            185
# Daddy Yankee        193
# Drake               205
# Ed Sheeran          220
# J Balvin            243
# Jhay Cortez         309
# Jonas Brothers      181
# Katy Perry          224
# Khalid              198
# Kygo                228
# Lady Gaga           216
# Lauv                199
# Lewis Capaldi       182
# Lil Nas X           157
# Lil Tecca           131
# Lizzo               173
# Lunay               266
# MEDUZA              153
# Maluma              176
# Marshmello          214
# Martin Garrix       164
# Nicky Jam           202
# Post Malone         175
# ROSALÍA             162
# Sam Smith           202
# Sech                288
# Shawn Mendes        191
# Taylor Swift        171
# The Chainsmokers    218
# Tones and I         210
# Y2K                 161
# ...

# %%
#df.groupby(['Artist.Name'])['Length.'].agg({'Length.':'mean'})

# %%
# how many songs share same populartity
df.groupby(['Popularity'])[['Track.Name']].count()
# Out:
#             Track.Name
# Popularity
# 70                   1
# 78                   1
# 79                   1
# 80                   1
# 82                   2
# 83                   2
# 84                   3
# 85                   1
# 86                   2
# 87                   4
# 88                   8
# 89                   8
# 90                   3
# 91                   7
# 92                   3
# 93                   1
# 94                   1
# 95                   1

# %%
df.groupby(['Popularity'])[['Track.Name']].count().shape
# Out:
# (18, 1)

# %%
df.groupby(['Genre'])['Length.','Danceability'].agg({'Danceability': max,'Length.':'mean'})
# Out:
# C:\Users\Joshi-PC\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                   Danceability     Length.
# Genre
# atl hip hop                 80  200.000000
# australian pop              82  210.000000
# big room                    66  164.000000
# boy band                    84  181.000000
# brostep                     69  198.000000
# canadian hip hop            84  193.000000
# canadian pop                76  191.000000
# country rap                 88  136.000000
# dance pop                   82  202.625000
# dfw rap                     76  166.500000
# edm                         69  218.666667
# electropop                  70  194.500000
# escape room                 72  173.000000
# latin                       80  225.200000
# panamanian pop              75  257.000000
# ...

# %%
df.groupby('Popularity')['Track.Name'].transform(list).rank()
# Out:
# 0     34.0
# 1      7.0
# 2     49.0
# 3      4.0
# 4     12.0
# 5     16.0
# 6     33.0
# 7     15.0
# 8     26.0
# 9     47.0
# 10     6.0
# 11    21.0
# 12    37.0
# 13    29.0
# 14    22.0
# 15    24.0
# 16    19.0
# 17    40.0
# 18    20.0
# 19    45.0
# 20    31.0
# 21    30.0
# 22    25.0
# 23    36.0
# 24    48.0
# 25    17.0
# 26    11.0
# 27    18.0
# 28     9.0
# 29    32.0
# 30    41.0
# 31     2.0
# 32     1.0
# 33    44.0
# 34    23.0
# 35    39.0
# 36    28.0
# 37     3.0
# 38    38.0
# 39    50.0
# 40    14.0
# 41    46.0
# 42    35.0
# 43    42.0
# 44     8.0
# 45    27.0
# 46    43.0
# 47    13.0
# 48     5.0
# 49    10.0
# Name: Track.Name, dtype: float64

# %%
df.groupby('Danceability')['Track.Name'].transform(list).rank()
# Out:
# 0     34.0
# 1      7.0
# 2     49.0
# 3      4.0
# 4     12.0
# 5     16.0
# 6     33.0
# 7     15.0
# 8     26.0
# 9     47.0
# 10     6.0
# 11    21.0
# 12    37.0
# 13    29.0
# 14    22.0
# 15    24.0
# 16    19.0
# 17    40.0
# 18    20.0
# 19    45.0
# 20    31.0
# 21    30.0
# 22    25.0
# 23    36.0
# 24    48.0
# 25    17.0
# 26    11.0
# 27    18.0
# 28     9.0
# 29    32.0
# 30    41.0
# 31     2.0
# 32     1.0
# 33    44.0
# 34    23.0
# 35    39.0
# 36    28.0
# 37     3.0
# 38    38.0
# 39    50.0
# 40    14.0
# 41    46.0
# 42    35.0
# 43    42.0
# 44     8.0
# 45    27.0
# 46    43.0
# 47    13.0
# 48     5.0
# 49    10.0
# Name: Track.Name, dtype: float64

# %%
plt.scatter(df['Beats.Per.Minute'],df['Popularity'])

# %%
plt.figure(figsize = (20,10))
sns.countplot('Popularity', hue = 'Energy' , data = df.head(5))

# %%
plt.figure(figsize = (20,10))
sns.countplot('Popularity',hue = 'Artist.Name' , data = df.tail(7),saturation=0.75)

# %%
plt.figure(figsize = (20,10))
sns.countplot('Popularity', data = df.head(5))

# %%
plt.boxplot(df['Popularity'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2d557136248>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2d557600188>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2d557593108>],
#  'medians': [<matplotlib.lines.Line2D at 0x2d557161988>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2d5570a7048>],
#  'means': []}

# %%
sns.distplot(df['Popularity'])

# %%
df= df.loc[:,['Artist.Name','Popularity']]
df.head()
# Out:
#      Artist.Name  Popularity
# 0   Shawn Mendes          79
# 1       Anuel AA          92
# 2  Ariana Grande          85
# 3     Ed Sheeran          86
# 4    Post Malone          94
